# %% [markdown]
# # Mel Frequency Cepstral Coefficients

# %%
import librosa

y, sr = librosa.load('dataset/auds/speech.wav')
print(y.shape, sr)
print(y)

print("Sample Rate:", sr)
print("Audio Duration:", len(y)/sr , "s")
print("MFCC \n", librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13))
# Out:
# (143325,) 22050
# [-0.01741219 -0.02801823 -0.00678538 ...  0.07099582  0.07085574
#   0.06547645]
# Sample Rate: 22050
# Audio Duration: 6.5 s
# MFCC
#  [[-248.61435   -216.96877   -216.65703   ... -245.33398   -245.62863
#   -247.28038  ]
#  [  57.316372    58.346825    60.36778   ...   65.993385    64.8139
#     62.594257 ]
#  [ -26.480894   -26.392693   -21.586956  ...  -18.739853   -22.586502
#    -21.304878 ]
#  ...
#  [  -3.9479704   -7.8836713   -8.887991  ...  -11.044308    -9.387686
#     -8.202282 ]
#  [  -1.6973919   -2.6633801    0.9568883 ...    1.0196338    0.4816866
#      1.7004157]
#  [ -10.553621   -10.334681    -5.8570127 ...   -1.9871914   -4.622781
#     -2.4092188]]
