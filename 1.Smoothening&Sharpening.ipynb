# %% [markdown]
# # Smoothening and Sharpening of Image

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Smoothening of Image

# %%
img = cv2.imread('dataset/imgs/lady.jpg')
blur = cv2.blur(img, (5,5))
smoothen_ = cv2.filter2D(img,-1, filter_)
plt.subplot(121)
plt.imshow(img)
plt.title('Original')
plt.xticks([])
plt.yticks([])
plt.subplot(122)
plt.imshow(blur)
plt.title('Blurred')
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# ## Sharpening of Image

# %%
img = cv2.imread('dataset/imgs/lady2.jpg')
filter_ = np.array([[-1,-1,-1], [-1,9,-1], [-1, -1, -1]])
sharpen_img = cv2.filter2D(img, -1, filter_)
plt.subplot(121)
plt.imshow(img)
plt.title('Original')
plt.xticks([])
plt.yticks([])
plt.subplot(122)
plt.imshow(sharpen_img)
plt.title('Sharpened')
plt.xticks([])
plt.yticks([])
plt.show()
